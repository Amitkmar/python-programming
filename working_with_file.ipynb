# %% [markdown]
# <a href="https://colab.research.google.com/github/Amitkmar/python-programming/blob/main/working_with_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f=open("test.txt",'w')

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# sample_data/  test.txt

# %%
f.write("this is my first file to write")
# Out:
# 30

# %%
f.close()

# %%
f=open("test.txt",'w')#purana data delete ho gya

# %%
f.write("this is my file")
# Out:
# 15

# %%
f.close()

# %%
#open in append mode data not delete purane wale ke saat add hoga
f=open("test.txt",'a')

# %%
f.write("hello my name is Amit Kumar")
# Out:
# 27

# %%
f.close()

# %%
data=open("test.txt",'r')

# %%
data.read()
# Out:
# 'this is my filehello my name is Amit Kumar'

# %%
#read data line by line
data.readline()
# Out:
# 'this is my filehello my name is Amit Kumar'

# %%
#seek ka matlab hai pointer ko wapas zero index pe daal do
data.seek(0)
# Out:
# 0

# %%
data.readine()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2368545286.py in <cell line: 0>()
# ----> 1 data.readine()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'readine'

# %%
data.seek(10)
# Out:
# 10

# %%
#10th index se data read krega
data.read()
# Out:
# ' filehello my name is Amit Kumar'

# %%
data1=open("test.txt",'r')

# %%
for i in data1 :
  print(i)
# Out:
# this is my filehello my name is Amit Kumar

# %%
#file ka size check krna ho to
import os
os.path.getsize("test.txt")
# Out:
# 42

# %%
#remove the file
os.remove("test.txt")

# %%
f=open("test.txt",'w')

# %%
f.write("this is my filehello my name is Amit Kumar")
# Out:
# 42

# %%
f.close()

# %%
#rename the file
os.rename("test.txt","new.txt")

# %%
#create a copy of a file
import shutil
shutil.copy("new.txt","copy_new.txt")
# Out:
# 'copy_new.txt'

# %%
with open("new.txt",'r') as f:
  print(f.read())
# Out:
# this is my filehello my name is Amit Kumar
